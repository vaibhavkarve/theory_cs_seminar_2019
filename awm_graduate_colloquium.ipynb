# %%
K4 = graphs.CompleteGraph(4)
Butterfly = Graph([(0,1), (0,2), (1,2), (0,3), (0,4), (3,4)])
Book = Graph([(2,3), (0,2), (2,1), (0,3), (3,1), (3,4), (2,4)])
show = graphs_list.show_graphs
Unsatisfiable_Graphs = graphics_array([G.plot(layout= "circular", graph_border=True) for G in [K4, Butterfly, Book]], 1, 3)

# %%
Unsatisfiable_Graphs
# Out:
# Graphics Array of size 1 x 3

# %% [markdown]
# # Boolean (un)Satisfiability $\longleftrightarrow$ Graph Theory
# ---
#
# Vaibhav Karve
#
# (joint work with Anil Hirani)
# <br /><br>
#
# **AWM Graduate Colloquium, 2019-02-20**
#
# University of Illinois at Urbana-Champaign

# %% [markdown]
# ## Who will go to the party?
# <img src="animal_party.jpg" />

# %% [markdown]
# ## Who will go to the party?
# ---
#
# 1. Ant will definitely go if Bison goes.
# <br />
#
# 2. Bison won't go if Cheetah goes.
# <br />
#
# 3. Cheetah cannot go unless Dodo goes.
# <br />
#
# 4. Bison and Dodo will go together or not at all.

# %% [markdown]
# ## Three possible solutions:
#
# 1. Only **Ant** goes.
# <br />
#
# 2. **Ant**, **Bison** and **Dodo** go.
# <br />
#
# 3. No one goes. 🙁

# %% [markdown]
# ## Who will go to the party?
#
# ---
#
# 1. Ant will definitely go if Bison goes.
# <br />
#
# 2. Bison won't go if Cheetah goes.
# <br />
#
# 3. Cheetah cannot go unless Dodo goes.
# <br />
#
# 4. Bison and Dodo will go together or not at all.
# <br />
#
# 5. <b style="color:blue;"> If the Ant goes, then the Cheetah must go.</b>
#
# ## Possible solutions:
#
# 1. ~~Only **Ant** goes.~~
# <br />
#
# 2. ~~**Ant**, **Bison** and **Dodo** go.~~
# <br />
#
# 3. No one goes.

# %% [markdown]
# ## Who will go to the party?
#
# ---
#
# 1. Ant will definitely go if Bison goes.
# <br />
#
# 2. Bison won't go if Cheetah goes.
# <br />
#
# 3. Cheetah cannot go unless Dodo goes.
# <br />
#
# 4. Bison and Dodo will go together or not at all.
# <br />
#
# 5. <b style="color:blue;"> If the Ant goes, then the Cheetah must go.</b>
# <br />
#
# 6. <b style="color:red;"> If the Dodo doesn't go, then the Ant must go.</b>
#
#
# ## Possible solutions:
#
# 1. ~~Only **Ant** goes.~~
# <br />
#
# 2. ~~**Ant**, **Bison** and **Dodo** go.~~
# <br />
#
# 3. ~~No one goes.~~

# %% [markdown]
# ## How many constraints is too many?

# %% [markdown]
# ## When is a party not happening?

# %% [markdown]
# ## Boolean Satisfiability (SAT)
#
# ---
#
# "When can we satisfy all the conditions?"
# <br /><br />
#
# "When do the conditions become un-satisfiable?"
# <br /><br />
#
# "Can we find an efficient algorithm to decide between the two?"

# %% [markdown]
# ### Questions?

# %% [markdown]
# ## Who cares about SAT?
# ---

# %% [markdown]
# Animal Kingdom party organizers

# %% [markdown]
# Stephen Cook & Leonid Levin<br>
# (first NP-complete problem)

# %% [markdown]
# Computer scientists & Logicians

# %% [markdown]
# Aspirant millionaires (P vs. NP)

# %% [markdown]
# ## Who else cares about SAT?
# ---

# %% [markdown]
# Graph theorists (graphists?)
#
#    - Find complete subgraphs
#    - Vertex cover problem
#    - Directed Hamiltonian cycle problem
#    - Undirected Hamiltonian cycle problem
#    - Graph coloring problem

# %% [markdown]
# Number theorists
#    - Partition problem
#    - Latin/Magic square problem

# %% [markdown]
# ## Who else cares about SAT?
# ---

# %% [markdown]
# Gamers
#    - Super Mario Bros.
#    - Donkey Kong
#    - Pokemon
#    - Optimal Rubik's cube moves

# %% [markdown]
# Political Analysts

# %% [markdown]
# City Planners

# %% [markdown]
# Businesses

# %% [markdown]
# ## Solving SAT is difficult

# %% [markdown]
# ### "When you don't know the answer, change the question!"

# %% [markdown]
# ## Modify the question
#
# ---
#
# 1. Ant will definitely go if Bison goes.
# <br><br>
#
# 2. Bison won't go if Cheetah goes.
# <br><br>
#
# 3. Cheetah cannot go unless Dodo goes.
# <br><br>
#
# 4. Bison and Dodo will go together or not at all.

# %% [markdown]
# ## Modify the question
#
# ---
#
# 1. Ant --------------------- Bison ----.
# <br>
#
# 2. Bison ----------- Cheetah ----.
# <br>
#
# 3. Cheetah ---------------- Dodo ----.
# <br>
#
# 4. Bison --- Dodo ------------------------------.

# %%
G = Graph([("Ant", "Bison"), ("Bison", "Cheetah"), ("Cheetah", "Dodo"), ("Bison", "Dodo")])
Modified_Problem = G.plot(vertex_size=2000, vertex_labels=True, figsize = (2,2), layout="circular")

# %%
Modified_Problem
# Out:
# Graphics object consisting of 9 graphics primitives

# %% [markdown]
# ## SAT $\longrightarrow$ Graph theory
#
# ### Animal kingdom party $\longmapsto$ Animal kingdom graph

# %% [markdown]
# ## When is the party not happening? (_unsatisfiability_)

# %% [markdown]
# Complicated graph $\implies$ Unsatisfiable party
#
# Sparse graph $\implies$ At least one solution exists

# %% [markdown]
# ## Satisfiable graphs:

# %%
Single_Edge = Graph([("Ant","Bison")]).plot(figsize=(2,3), vertex_size=1000)

# %%
Single_Edge
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# ## Satisfiable graphs:

# %%
Double_Edge = Graph([("Ant","Bison"), ("Bison", "Cheetah")]).plot(figsize=(2,2), vertex_size=1900)

# %%
Double_Edge
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# ## Satisfiable graphs:

# %%
Triangle = Graph([("Ant","Bison"), ("Bison", "Cheetah"), ("Cheetah", "Ant")]).plot(figsize=(2,2), vertex_size=1900)

# %%
Triangle
# Out:
# Graphics object consisting of 7 graphics primitives

# %% [markdown]
# ## Satisfiable graph:

# %%
Polygon = graphs.CycleGraph(9).plot(figsize=(2,2))

# %%
Polygon
# Out:
# Graphics object consisting of 19 graphics primitives

# %% [markdown]
# # How we looked for unsatisfiable graphs

# %% [markdown]
# ### Lots of computer code

# %% [markdown]
# ### Lots of graph operations
#
#   - Subgraphing
#   - Edge-deletion
#   - Vertex-deletion
#   - Edge-contractions
#   - Reduction of cycles
#   - Reduction of multi-edges

# %% [markdown]
# ## Unsatisfiable graphs:

# %%
UF1 = [graphs.CompleteGraph(4)]
G = graphs.CompleteGraph(4).copy()
G.add_edge(0,4); G.add_edge(3,4); G.delete_edge(0,3)
UF1.insert(0, G.copy())
G.add_edge(0,5); G.add_edge(4,5); G.delete_edge(0,4)
UF1.insert(0, G.copy())
G.add_edge(0,6); G.add_edge(5,6); G.delete_edge(0,5)
UF1.insert(0, G.copy())

G = graphs.CompleteGraph(4)
UF1.insert(0, G.copy())
G.add_edge(3,4)
UF1.insert(0, G.copy())
G.add_edge(4,5)
UF1.insert(0, G.copy())
G.add_edge(5,6)
UF1.insert(0, G.copy())

Unsatisfiable_Family_1 = graphics_array([G.plot(layout= "circular", graph_border=True) for G in UF1], 3, 4)

# %%
Unsatisfiable_Family_1
# Out:
# Graphics Array of size 3 x 4

# %% [markdown]
# ## Unsatisfiable graphs:

# %%
UF2 = [Graph([(0,1), (0,2), (1,2), (0,3), (0,4), (3,4)])]
UF2.insert(0, Graph([(0,1), (1,2), (2,3), (3,0), (0,4), (4,5), (5,0)]))
UF2.insert(0, Graph([(0,1), (1,2), (2,3), (3,0), (0,4), (4,5), (5,6), (6,0)]))
UF2.insert(0, Graph([(0,1), (1,2), (2,3), (3,4), (4,0), (0,5), (5,6), (6,7), (7,0)]))

Unsatisfiable_Family_2 = graphics_array([G.plot(layout= "circular", graph_border=True) for G in UF2], 1, 4)

# %%
Unsatisfiable_Family_2
# Out:
# Graphics Array of size 1 x 4

# %% [markdown]
# ## Unsatisfiable graphs:

# %%
UF3 = [Graph([(2,3), (2,1), (2,0), (2,4), (3,0), (3,1), (3,4)])]
UF3.insert(0, Graph([(3,4), (3,0), (2,1), (3,2), (3,6), (4,0), (4,1), (4, 5), (5,6)]))
#UF3.insert(0, Graph([(0,1), (1,2), (2,3), (3,0), (0,4), (4,5), (5,0)]))

Unsatisfiable_Family_3 = graphics_array([G.plot(layout= "circular", graph_border=True) for G in UF3], 3, 3)

# %%
Unsatisfiable_Family_3
# Out:
# Graphics Array of size 3 x 3

# %% [markdown]
# # Main result
#
# ## The following graphs are obstructions to satisfiability:

# %%
Unsatisfiable_Graphs
# Out:
# Graphics Array of size 1 x 3

# %% [markdown]
# # Main result
#
# ## The following graphs are obstructions to satisfiability:

# %% [markdown]
# <table>
# <td><img src="K4.png" /></td>
# <td><img src="Butterfly.png"/></td>
# <td><img src="K23.png"/></td>
# </table>
#
# ## _Minimal criminals!_

# %% [markdown]
# # Links
#
#  - Wikipedia entry on Boolean satisfiability problem: [en.wikipedia.org/wiki/Boolean_satisfiability_problem](https://en.wikipedia.org/wiki/Boolean_satisfiability_problem)
#
# - Wikipedia list of NP-complete problems: [en.wikipedia.org/wiki/List_of_NP-complete_problems](https://en.wikipedia.org/wiki/List_of_NP-complete_problems)
#
#
# - Our paper on arXiv: **The complete set of minimal simple graphs that support unsatisfiable 2-CNFs**  [arxiv.org/abs/1812.10849](https://arxiv.org/abs/1812.10849)
